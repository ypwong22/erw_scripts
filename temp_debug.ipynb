# %%
import numpy as np
import pandas as pd
import xarray as xr
from glob import glob
import os

# %%
path_root = "/gpfs/wolf2/cades/cli185/proj-shared/zdr/ERW/output/UQ/pft1/20250529_conus_ICB20TRCNPRDCTCBC_erw_pft1_ens0071/run"

file_list = glob(os.path.join(path_root, "*.h1.*.nc"))[:-1]

hr = xr.open_mfdataset(file_list)

# %%
data = hr['r_precip_vr_2'].sel(lat = 44.75, lon = 290.25)

# %%
data[:, 0].values
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.81807430e-10, 1.49178100e-10,
#        9.57906116e-11, 1.31165148e-10, 1.24937075e-10, 1.06512452e-10,
#        1.22917052e-10, 1.26151548e-10, 9.87715257e-11, 1.12820794e-10,
#        1.16853680e-10, 9.71409342e-11, 1.22550872e-10, 1.11912431e-10,
#        1.25302685e-10, 1.12805480e-10, 1.11323707e-10, 1.01372889e-10,
#        1.01503146e-10, 1.00212651e-10, 1.24293603e-10, 1.12428095e-10,
#        1.32542755e-10, 1.12748984e-10, 1.20797664e-10, 1.57248672e-10,
#        1.64058059e-10, 1.52776722e-10, 1.35445780e-10, 1.67493491e-10,
#        1.47990828e-10, 1.85044313e-10, 2.10122086e-10, 2.09054149e-10],
#       dtype=float32)
