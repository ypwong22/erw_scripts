# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the map of United States
usa = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Filter for contiguous US states
contiguous_usa = usa[(usa.name != "Alaska") & (usa.name != "Hawaii")]

# Define the coordinates for the stars
star1 = (-71.728825, 43.9556695)  # Coordinates for the first star
star2 = (-121.781708, 38.531656)  # Coordinates for the second star

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
contiguous_usa.plot(ax=ax, color='white', edgecolor='black')
ax.scatter(*star1, color='blue', s=100, marker='*', label='Hubbard Brook')
ax.scatter(*star2, color='red', s=100, marker='*', label='UC Davis')
ax.set_xlim([-130, -50])
ax.set_ylim([25, 50])
ax.legend(loc = 'lower right')
plt.show()
