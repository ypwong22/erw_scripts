# %%
import xarray as xr
import os
import matplotlib.pyplot as plt

# %%
hr = xr.open_mfdataset("/gpfs/wolf2/cades/cli185/proj-shared/zdr/ERW/output/20250507_debug_ICB20TRCNPRDCTCBC_erw/run/20250507_debug_ICB20TRCNPRDCTCBC_erw.elm.h1.2050*.nc")

# %%
hr['cation_vr_1'][:, 8, 0].plot()

# %%
hr['secondary_mineral'][0, 0, :, :].plot()

# %%
hr['secondary_mineral'][41, 0, :, :].plot()
